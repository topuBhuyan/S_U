# %%
"""  বিভিন্ন model import করবো কিবাভে ?  """

# Pandas
import pandas as pd

# numpy
import numpy as np

# লজিস্টিক রিগ্রেশন
from sklearn.linear_model import LogisticRegression

# ডিসিশন ট্রি
from sklearn.tree import DecisionTreeClassifier

# লিনিয়ার রিগ্রেশন
from sklearn.linear_model import LinearRegression

# KMeans
from sklearn.cluster import KMeans

# matplotlib
import matplotlib.pyplot as plt

# iris
from sklearn.datasets import load_iris

# ৩ডি প্লটের জন্য
from mpl_toolkits.mplot3d import Axes3D

# স্ট্যাটিস্টিক্যাল ভিজুয়ালাইজেশনের জন্য
import seaborn as sns

# ডেটাকে ট্রেন ও টেস্ট সেটে ভাগ করার jonno
from sklearn.model_selection import train_test_split

# for file upload ar jonno
from google.colab import files

# %%
# file upload
files.upload()
# Out:
#      <input type="file" id="files-b58d9509-443c-4776-ba67-f5d2b6413aa0" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-b58d9509-443c-4776-ba67-f5d2b6413aa0">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# file Read
df = pd.read_csv('/content/Salary_Data (1).csv')

# %%
# data show
df.sample(10)
# Out:
#     YearsExperience  Salary
# 23              8.2  113812
# 11              NaN   55794
# 7               3.2   54445
# 6               NaN   60150
# 28             10.3  122391
# 22              7.9  101302
# 19              6.0   93940
# 1               1.3   46205
# 18              5.9   81363
# 29             10.5  121872

# %%
#

# %%
iris = load_iris()
x = iris.data
y = iris.target

# %%
""" Dataset set split  করবো কিবাভে ? """
"""
split করার আগে উপরের ৩ টা লাইন ডিক্লেয়ার করতে হবে না হলে error দেখাবে ! যেমন:  'x' is not defined
'y ' is not defined
"""
x_train, x_test, y_train, y_test = train_test_split(
    x, y,
    test_size = 0.2, # ২০% ডেটা টেস্ট, ৮০% ট্রেন।
    random_state = 42, # ফলাফল রিপিট করতে

)

# %%
""" Model Training , Testing, করবো কিভাবে ? """

# মডেল ট্রেন
model = LogisticRegression()
model.fit(x_train, y_train)

# মডেল টেস্ট করা
accuracy = model.score(x_test, y_test)
print(f"Accuracy: {accuracy}")
# Out:
# Accuracy: 1.0

# %%
#

# %%
""" Data Predication করবো কিভাবে ? """
y_pred = model.predict(x_test)
y_pred_proba = model.predict_proba(x_test)

# z = w1 * x + w0
# y_pred = sigmoid(z)
# print(y_pred)

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score

# %%
"""  Confusion metric classification কি
এটা মডেলের প্রেডিকশন কতটা সঠিক/ভুল হয়েছে তা দেখানোর একটি টেবিল। """

# গুরুত্বপূর্ণ মেট্রিক্স বের করা যেমন : একুরেসি, প্রিসিশন, রিকল বের করা

# Accuracy
accuracy = accuracy_score(y_test, y_pred)

# Precisin
precision = precision_score(y_test, y_pred)

# Recall
recall = recall_score(y_test, y_pred)


print(f"Accuracy: {accuracy:.2f}")
print(f"Precision: {precision:.2f}")
print(f"Recall: {recall:.2f}")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_794/2304709402.py in <cell line: 0>()
#      11
#      12 # Recall
# ---> 13 recall = recall_score(y_test, y_pred)
#      14
#      15
#
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/_param_validation.py in wrapper(*args, **kwargs)
#     214                     )
#     215                 ):
# --> 216                     return func(*args, **kwargs)
#     217             except InvalidParameterError as e:
#     218                 # When the function is just a wrapper around an estimator, we allow
#
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py in recall_score(y_true, y_pred, labels, pos_label, average, sample_weight, zero_division)
#    2427     array([1. , 1. , 0.5])
#    2428     """
# -> 2429     _, r, _, _ = precision_recall_fscore_support(
#    2430         y_true,
# ...

# %%
# Performance Metrics (পারফরম্যান্স মেট্রিক্স) কি?
# মেট্রিক্স গুলো বলে দেয় আপনার মডেল কতটা ভালো কাজ করছে।

# %%
from sklearn.metrics import classification_report
#F1 = 2 x (Precision x Recall) / (Precision + Recall)

print(classification_report(y_test, y_pred_class))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        10
#            1       0.45      1.00      0.62         9
#            2       0.00      0.00      0.00        11
#
#     accuracy                           0.63        30
#    macro avg       0.48      0.67      0.54        30
# weighted avg       0.47      0.63      0.52        30
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
# ...

# %%
# কে মডেল ফিট করে এবং প্রেডিকশন করে?
# আপনার Logistic Regression কোডে, মডেল ফিট করা এবং প্রেডিকশন করা হচ্ছে
from sklearn.metrics import accuracy_score, confusion_matrix

# %%
# মডেল ফিট করা (Training)
model = LogisticRegression()
model.fit(x_train, y_train)

print("\n মডেল ট্রেনিং সম্পন্ন!")
print(f"মডেলের coef (w1): {model.coef_[0][0]:.4f}")
print(f"মডেলের intercept (w0): {model.intercept_[0]:.4f}")
# Out:
#  মডেল ট্রেনিং সম্পন্ন!
# মডেলের coef (w1): -0.3935
# মডেলের intercept (w0): 9.0088

# %%
#  প্রেডিকশন করা
y_pred = model.predict(x_test)
y_pred_proba = model.predict_proba(x_test)


print("\n" + "="*50)
print("প্রেডিকশন ফলাফল:")
print("="*50)
# Out:
# ...
# প্রেডিকশন ফলাফল:
# ...

# %%
# একুরেসি
accuracy = accuracy_score(y_test, y_pred)
print("Model Accuracy: {accuracy*100:.2f}%")
# Out:
# Model Accuracy: {accuracy*100:.2f}%

# %%
# কনফিউশন ম্যাট্রিক্স
cm = confusion_matrix(y_test, y_pred)
print("\n Confusion Matrix :")
print(cm)
# Out:
#  Confusion Matrix :
# [[10  0  0]
#  [ 0  9  0]
#  [ 0  0 11]]
